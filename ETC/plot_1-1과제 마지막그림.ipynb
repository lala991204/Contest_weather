# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame([[0.735,0.732,0.732,0.718],[0.651,0.672,0.668,0.646],[0.637,0.633,0.637,0.620]])
df1 = df.T
df1
df1.columns = ['XGB', 'Tabnet', 'LGBM']
df1
# Out:
#      XGB  Tabnet   LGBM
# 0  0.735   0.651  0.637
# 1  0.732   0.672  0.633
# 2  0.732   0.668  0.637
# 3  0.718   0.646  0.620

# %%
# penguins_dropna = penguins.dropna()

# sns.boxplot(y='0',x='0',data=df1)
plt.boxplot(df1)
# plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12360/2644991648.py in <module>
#       2
#       3 # sns.boxplot(y='0',x='0',data=df1)
# ----> 4 plt.boxplot(df1)
#       5 # plt.legend()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2689         whiskerprops=None, manage_ticks=True, autorange=False,
#    2690         zorder=None, *, data=None):
# -> 2691     return gca().boxplot(
#    2692         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2693         positions=positions, widths=widths, patch_artist=patch_artist,
#
# ...

# %%
# sns.set(default)
# data = {}
# data['a'] = np.arange(12)+1
# data['b'] = np.arange(14)+1
# data['c'] = np.arange(8)+1

color_dict = {'XGB':'orange', 'Tabnet':'blue', 'LGBM':'green'}
controls = ['XGB', 'Tabnet', 'LGBM']

fig, ax = plt.subplots()

boxplot_dict = ax.boxplot(
    [df1[x] for x in ['XGB', 'Tabnet', 'LGBM']],
    positions = [1, 1.5, 2],
    labels = controls, 
    # patch_artist = True,  # Legend isn't working with patch objects.. 
    widths = 0.25)

# i=0
# for b in boxplot_dict['boxes']:
#     lab = ax.get_xticklabels()[i].get_text()
# #     print("Label property of box {0} is {1}".format(i, lab))
#     b.set_color(color_dict[lab])
#     b.set_label(lab)
#     i += 1
plt.style.use('default')
# ax.set_ylim([0,16])
# ax.legend()
plt.xlabel('Model', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.savefig('box1.png')
plt.show()
# boxplot_dict['boxes'][0].set_color('orange')

# %%
df1['method'] = ['그룹화 하지 않음', '그룹화1', '그룹화2', '그룹화3']
df1
# Out:
#      XGB  Tabnet   LGBM     method
# 0  0.735   0.651  0.637  그룹화 하지 않음
# 1  0.732   0.672  0.633       그룹화1
# 2  0.732   0.668  0.637       그룹화2
# 3  0.718   0.646  0.620       그룹화3

# %%
color_dict = {'no_group':'orange', 'group1':'blue', 'group2':'green', 'group3':'red'}
controls = ['no_group', 'group1', 'group2', 'group3']

fig, ax = plt.subplots()

boxplot_dict = ax.boxplot(
    [df[x] for x in ['no_group', 'group1', 'group2', 'group3']],
    positions = [1, 1.5, 2, 2.5],
    labels = controls, 
    # patch_artist = True,  # Legend isn't working with patch objects.. 
    widths = 0.25)

# i=0
# for b in boxplot_dict['boxes']:
#     lab = ax.get_xticklabels()[i].get_text()
# #     print("Label property of box {0} is {1}".format(i, lab))
#     b.set_color(color_dict[lab])
#     b.set_label(lab)
#     i += 1

# ax.set_ylim([0,16])
# ax.legend()
plt.tight_layout()
# plt.savefig('box1.png')
plt.show()

# %%
df
df['model'] = ['XGB','Tabnet', 'LGBM']
# df = df.set_index('name')
df
# Out:
#         no_group  group1  group2  group3    name   model
# name
# XGB        0.735   0.732   0.732   0.718     XGB     XGB
# Tabnet     0.651   0.672   0.668   0.646  Tabnet  Tabnet
# LGBM       0.637   0.633   0.637   0.620    LGBM    LGBM

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\Windows\\Fonts\\MISTRAL.TTF',
#  'C:\\WINDOWS\\Fonts\\palabi.ttf',
#  'C:\\WINDOWS\\Fonts\\STXINWEI.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'C:\\WINDOWS\\Fonts\\TCB_____.TTF',
#  'C:\\WINDOWS\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\WINDOWS\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\WINDOWS\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\WINDOWS\\Fonts\\NGULIM.TTF',
#  'C:\\WINDOWS\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\BOD_CBI.TTF',
#  'C:\\WINDOWS\\Fonts\\H2GSRB.TTF',
#  'C:\\WINDOWS\\Fonts\\STXIHEI.TTF',
#  'C:\\WINDOWS\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\WINDOWS\\Fonts\\ROCCB___.TTF',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\CALIFR.TTF',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  'C:\\WINDOWS\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
# ...

# %%
from matplotlib import font_manager, rc
font_path ='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12360/1152189224.py in <module>
#       1 from matplotlib import font_manager, rc
#       2 font_path ='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# ----> 3 font = font_manager.FontProperties(fname=font_path).get_name()
#       4 rc('font', family=font)
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     722         Return the name of the font that best matches the font properties.
#     723         """
# --> 724         return get_font(findfont(self)).family_name
#     725
#     726     def get_style(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1422         hinting_factor = rcParams['text.hinting_factor']
#    1423     # also key on the thread ID to prevent segfaults with multi-threading
# ...

# %%
from matplotlib import rc
import matplotlib.font_manager as fm

fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:\\WINDOWS\\Fonts\\GOTHICI.TTF'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12360/481974726.py in <module>
#       2 import matplotlib.font_manager as fm
#       3
# ----> 4 fm._rebuild()
#       5 fm.get_fontconfig_fonts()
#       6
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

sns.barplot(x = 'no_group', y='model', palette='Set2', data=df, ax=ax1)
sns.barplot(x = 'group1', y='model', palette='Set2', data=df, ax=ax2)
sns.barplot(x = 'group2', y='model', palette='Set2', data=df, ax=ax3)
sns.barplot(x = 'group3', y='model', palette='Set2', data=df, ax=ax4)
# plt.legend(bbox_to_anchor=(1.05, 1))
# sns.set(font_scale = 1.5)
plt.tight_layout()
ax1.tick_params(labelsize=20)
ax1.set_xlabel("그룹화 하지 않음", fontsize=30)
ax1.set_ylabel("Model", fontsize=30)

plt.savefig('box2.png')
# Out:
# C:\Users\wjd72\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjd72\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47353 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjd72\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjd72\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjd72\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
