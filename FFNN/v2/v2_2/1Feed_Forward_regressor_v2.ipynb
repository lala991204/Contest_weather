# %% [markdown]
# # Feed Forward Neural Networks

# %%
# jupyter notebook

# %%
### 210701~210711, 210821~210831 검증기간(총 22일간)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras import Input
from keras.layers import Dense

import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras.callbacks import ModelCheckpoint
from keras.models import load_model
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.

# %% [markdown]
# # Train

# %%
cd C:\weather\data\train
# Out:
# C:\weather\data\train

# %%
forders_tr = os.listdir()
forders_tr
# Out:
# ['table_202001.csv',
#  'table_202002.csv',
#  'table_202003.csv',
#  'table_202004.csv',
#  'table_202005.csv',
#  'table_202006.csv',
#  'table_202007.csv',
#  'table_202008.csv',
#  'table_202009.csv',
#  'table_202010.csv',
#  'table_202011.csv',
#  'table_202012.csv',
#  'table_202101.csv',
#  'table_202102.csv',
#  'table_202103.csv',
#  'table_202104.csv',
#  'table_202105.csv',
#  'table_202106.csv']

# %%
# 새로운 데이터 프레임 생성
train = pd.DataFrame()

for files in forders_tr:
    df= pd.read_csv(files)
    train = pd.concat([train, df])

# %%
train
# Out:
#         YearMonthDayHourMinute  STN        Lon       Lat  isitu-LST    Band1  \
# 0                 202001010000   90  128.56473  38.25085       -2.6  0.00000
# 1                 202001010000   95  127.30420  38.14787       -2.6 -0.00057
# 2                 202001010000   98  127.06070  37.90188       -3.1  0.00000
# 3                 202001010000   99  126.76648  37.88589       -3.4 -0.00057
# 4                 202001010000  101  127.73570  37.90262       -3.6 -0.00057
# ...                        ...  ...        ...       ...        ...      ...
# 447705            202106302350  973  126.94961  35.02330       23.6 -0.00057
# 447706            202106302350  974  128.15605  35.24435       20.7  0.00000
# 447707            202106302350  977  127.46688  36.72455       23.9 -0.00057
# 447708            202106302350  978  127.77626  37.95461       23.2 -0.00057
# 447709            202106302350  980  126.48951  33.26062       24.2  0.00000
#
#           Band2    Band3    Band4   Band5  ...  Year  Month  Day  Hour  \
# 0       0.00000 -0.00060 -0.00030 -0.0003  ...  2020      1    1     0
# 1      -0.00057  0.00030 -0.00060 -0.0003  ...  2020      1    1     0
# 2       0.00000  0.00030  0.00060 -0.0003  ...  2020      1    1     0
# 3      -0.00057 -0.00030  0.00015  0.0000  ...  2020      1    1     0
# 4       0.00000  0.00030  0.00030  0.0000  ...  2020      1    1     0
# ...         ...      ...      ...     ...  ...   ...    ...  ...   ...
# 447705 -0.00057 -0.00179 -0.00060 -0.0003  ...  2021      6   30    23
# 447706 -0.00057  0.00089  0.00015  0.0000  ...  2021      6   30    23
# 447707 -0.00057 -0.00060  0.00015  0.0000  ...  2021      6   30    23
# 447708  0.00000  0.00030 -0.00075 -0.0003  ...  2021      6   30    23
# 447709 -0.00057  0.00000 -0.00015 -0.0003  ...  2021      6   30    23
#
#         Minute  mean_6_23  mean_34_37  mean_38_39  mean_40_42  mean_43_44
# 0            0   0.422121    0.000000    0.000000    0.000000    0.868476
# 1            0  -0.391234    0.000000    0.000000    0.000000    1.114533
# 2            0  -0.355405    0.000000    0.000000    0.000000    1.315872
# 3            0  -0.332510    0.000000    0.000000    0.000000    1.666385
# 4            0  -0.188191   -1.022277   -0.499305    0.114355    1.402172
# ...        ...        ...         ...         ...         ...         ...
# 447705      50   0.000385    1.107697    1.107273    0.000000    0.209894
# 447706      50   0.071010    1.472452    1.488681    0.000000    0.000000
# 447707      50  -0.144802    1.049685    1.210674    0.000000    0.000000
# 447708      50  -0.365471    0.726721    0.740235    0.000000    0.000000
# 447709      50   0.154993    1.010960    1.339413    0.000000    0.000000
#
# [8202668 rows x 54 columns]

# %% [markdown]
# # Validation

# %%
cd C:\weather\data\val
# Out:
# C:\weather\data\val

# %%
forders_val = os.listdir()
forders_val
# Out:
# ['table_202109.csv',
#  'table_202110.csv',
#  'table_202111.csv',
#  'table_202112.csv']

# %%
# 새로운 데이터 프레임 생성
val = pd.DataFrame()

for files in forders_val:
    df= pd.read_csv(files)
    val = pd.concat([val, df])

# %%
val
# Out:
#         YearMonthDayHourMinute  STN        Lon       Lat  isitu-LST    Band1  \
# 0                 202109010000   90  128.56473  38.25085       17.9  0.00170
# 1                 202109010000   93  127.75443  37.94738       19.0  0.00170
# 2                 202109010000   95  127.30420  38.14787       17.6  0.00170
# 3                 202109010000   98  127.06070  37.90188       19.3  0.00227
# 4                 202109010000   99  126.76648  37.88589       19.6  0.00227
# ...                        ...  ...        ...       ...        ...      ...
# 432625            202112312350  702  126.99435  35.94504       -3.2 -0.00057
# 432626            202112312350  972  128.68340  36.54983       -4.8 -0.00057
# 432627            202112312350  973  126.94961  35.02330       -2.4  0.00000
# 432628            202112312350  974  128.15605  35.24435       -1.8 -0.00057
# 432629            202112312350  980  126.48951  33.26062        4.5 -0.00057
#
#           Band2    Band3    Band4    Band5  ...  Year  Month  Day  Hour  \
# 0       0.00171  0.00238  0.00195  0.00181  ...  2021      9    1     0
# 1       0.00171  0.00149  0.00180  0.00121  ...  2021      9    1     0
# 2       0.00228  0.00179  0.00195  0.00151  ...  2021      9    1     0
# 3       0.00228  0.00238  0.00374  0.00181  ...  2021      9    1     0
# 4       0.00228  0.00268  0.00239  0.00151  ...  2021      9    1     0
# ...         ...      ...      ...      ...  ...   ...    ...  ...   ...
# 432625 -0.00057 -0.00030 -0.00045 -0.00030  ...  2021     12   31    23
# 432626  0.00057  0.00089 -0.00015  0.00000  ...  2021     12   31    23
# 432627 -0.00057 -0.00179  0.00015 -0.00030  ...  2021     12   31    23
# 432628 -0.00057  0.00060 -0.00015  0.00000  ...  2021     12   31    23
# 432629 -0.00057 -0.00268 -0.00090  0.00000  ...  2021     12   31    23
#
#         Minute  mean_6_23  mean_34_37  mean_38_39  mean_40_42  mean_43_44
# 0            0  -0.733944    0.000000    0.000000    0.000000    0.508451
# 1            0  -0.696051   -0.914975    0.447435    0.341129   -0.179931
# 2            0  -0.279810    0.000000    0.000000    0.000000   -0.365214
# 3            0  -0.195837    0.000000    0.000000    0.000000   -0.290579
# 4            0  -0.370219    0.000000    0.000000    0.000000    0.015434
# ...        ...        ...         ...         ...         ...         ...
# 432625      50  -0.787369   -1.417396   -1.534663    0.000000    0.000000
# 432626      50  -0.672741   -1.492066   -1.894582    0.000000    1.185870
# 432627      50  -0.684352   -0.847900   -0.716603    0.000000    1.525860
# 432628      50  -2.065335   -1.364155   -0.756098    0.000000    0.000000
# 432629      50  -0.805391    0.495546    1.334551    0.000000    0.000000
#
# [1780159 rows x 54 columns]

# %% [markdown]
# # Test

# %%
cd C:\weather\data\test
# Out:
# C:\weather\data\test

# %%
forders_te = os.listdir()
forders_te
# Out:
# ['table_202107_1.csv', 'table_202108_2.csv']

# %%
### 210701~210711, 210821~210831 검증기간(총 22일간)

# 새로운 데이터 프레임 생성
test = pd.DataFrame()

for files in forders_te:
    df= pd.read_csv(files)
    test = pd.concat([test, df])

# %%
test
# Out:
#        YearMonthDayHourMinute  STN        Lon       Lat    Band1    Band2  \
# 0                202107000000   90  128.56473  38.25085 -0.00057 -0.00057
# 1                202107000000   93  127.75443  37.94738 -0.00057 -0.00057
# 2                202107000000   95  127.30420  38.14787 -0.00057 -0.00057
# 3                202107000000   98  127.06070  37.90188 -0.00057 -0.00057
# 4                202107000000   99  126.76648  37.88589 -0.00057  0.00000
# ...                       ...  ...        ...       ...      ...      ...
# 27087            202108000000  973  126.94961  35.02330  0.00000  0.00000
# 27088            202108000000  974  128.15605  35.24435  0.00000  0.00057
# 27089            202108000000  977  127.46688  36.72455  0.00000  0.00057
# 27090            202108000000  978  127.77626  37.95461  0.00000  0.00000
# 27091            202108000000  980  126.48951  33.26062  0.00000  0.00000
#
#          Band3    Band4    Band5    Band6  ...  Year  Month  Day  Hour  \
# 0     -0.00149 -0.00045 -0.00060  0.00000  ...  2021      7    0     0
# 1     -0.00119  0.00000  0.00000 -0.00065  ...  2021      7    0     0
# 2     -0.00060  0.00015  0.00000 -0.00065  ...  2021      7    0     0
# 3      0.00030 -0.00015 -0.00030 -0.00065  ...  2021      7    0     0
# 4     -0.00060 -0.00105  0.00000 -0.00065  ...  2021      7    0     0
# ...        ...      ...      ...      ...  ...   ...    ...  ...   ...
# 27087  0.00030  0.00015  0.00121  0.00000  ...  2021      8    0     0
# 27088  0.00000  0.00015  0.00000  0.00000  ...  2021      8    0     0
# 27089 -0.00179  0.00030  0.00000  0.00000  ...  2021      8    0     0
# 27090  0.00089  0.00015 -0.00030  0.00000  ...  2021      8    0     0
# 27091  0.00030 -0.00015  0.00000  0.00000  ...  2021      8    0     0
#
#        Minute  mean_6_23  mean_34_37  mean_38_39  mean_40_42  mean_43_44
# 0           0  -0.137869    0.000000    0.000000    0.000000    0.503333
# 1           0   0.115111   -0.141101    0.027567   -0.354792    0.074239
# 2           0  -0.072823    0.000000    0.000000    0.000000   -0.073873
# 3           0   0.138902    0.000000    0.000000    0.000000    0.065445
# 4           0   0.177468    0.000000    0.000000    0.000000    0.444882
# ...       ...        ...         ...         ...         ...         ...
# 27087       0  -0.207862    1.366354    0.637043    0.000000    0.664962
# 27088       0  -0.559507    1.766315    1.253310    0.000000    0.000000
# 27089       0  -0.449989   -0.705848   -0.467874    0.000000    0.000000
# 27090       0  -0.374500   -1.392848   -0.768451    0.000000    0.000000
# 27091       0  -1.146268    1.806430    1.136602    0.000000    0.000000
#
# [54503 rows x 52 columns]

# %% [markdown]
# # Submission

# %%
cd C:\weather\data
# Out:
# C:\weather\data

# %%
# Set Pandas options to display more columns
# pd.options.display.max_columns=50
submission=pd.read_csv('1-2_검증데이터셋.csv', encoding='utf-8')
submission
# Out:
#        YearMonthDayHourMinute  STN  isitu-LST  insitu-TA
# 0                202107010030   90        NaN        NaN
# 1                202107010030   93        NaN        NaN
# 2                202107010030   95        NaN        NaN
# 3                202107010030   98        NaN        NaN
# 4                202107010030   99        NaN        NaN
# ...                       ...  ...        ...        ...
# 54498            202108312330  973        NaN        NaN
# 54499            202108312330  974        NaN        NaN
# 54500            202108312330  977        NaN        NaN
# 54501            202108312330  978        NaN        NaN
# 54502            202108312330  980        NaN        NaN
#
# [54503 rows x 4 columns]

# %% [markdown]
# # 모델 Train

# %%
train
# Out:
#         YearMonthDayHourMinute  STN        Lon       Lat  isitu-LST    Band1  \
# 0                 202001010000   90  128.56473  38.25085       -2.6  0.00000
# 1                 202001010000   95  127.30420  38.14787       -2.6 -0.00057
# 2                 202001010000   98  127.06070  37.90188       -3.1  0.00000
# 3                 202001010000   99  126.76648  37.88589       -3.4 -0.00057
# 4                 202001010000  101  127.73570  37.90262       -3.6 -0.00057
# ...                        ...  ...        ...       ...        ...      ...
# 447705            202106302350  973  126.94961  35.02330       23.6 -0.00057
# 447706            202106302350  974  128.15605  35.24435       20.7  0.00000
# 447707            202106302350  977  127.46688  36.72455       23.9 -0.00057
# 447708            202106302350  978  127.77626  37.95461       23.2 -0.00057
# 447709            202106302350  980  126.48951  33.26062       24.2  0.00000
#
#           Band2    Band3    Band4   Band5  ...  Year  Month  Day  Hour  \
# 0       0.00000 -0.00060 -0.00030 -0.0003  ...  2020      1    1     0
# 1      -0.00057  0.00030 -0.00060 -0.0003  ...  2020      1    1     0
# 2       0.00000  0.00030  0.00060 -0.0003  ...  2020      1    1     0
# 3      -0.00057 -0.00030  0.00015  0.0000  ...  2020      1    1     0
# 4       0.00000  0.00030  0.00030  0.0000  ...  2020      1    1     0
# ...         ...      ...      ...     ...  ...   ...    ...  ...   ...
# 447705 -0.00057 -0.00179 -0.00060 -0.0003  ...  2021      6   30    23
# 447706 -0.00057  0.00089  0.00015  0.0000  ...  2021      6   30    23
# 447707 -0.00057 -0.00060  0.00015  0.0000  ...  2021      6   30    23
# 447708  0.00000  0.00030 -0.00075 -0.0003  ...  2021      6   30    23
# 447709 -0.00057  0.00000 -0.00015 -0.0003  ...  2021      6   30    23
#
#         Minute  mean_6_23  mean_34_37  mean_38_39  mean_40_42  mean_43_44
# 0            0   0.422121    0.000000    0.000000    0.000000    0.868476
# 1            0  -0.391234    0.000000    0.000000    0.000000    1.114533
# 2            0  -0.355405    0.000000    0.000000    0.000000    1.315872
# 3            0  -0.332510    0.000000    0.000000    0.000000    1.666385
# 4            0  -0.188191   -1.022277   -0.499305    0.114355    1.402172
# ...        ...        ...         ...         ...         ...         ...
# 447705      50   0.000385    1.107697    1.107273    0.000000    0.209894
# 447706      50   0.071010    1.472452    1.488681    0.000000    0.000000
# 447707      50  -0.144802    1.049685    1.210674    0.000000    0.000000
# 447708      50  -0.365471    0.726721    0.740235    0.000000    0.000000
# 447709      50   0.154993    1.010960    1.339413    0.000000    0.000000
#
# [8202668 rows x 54 columns]

# %%
##### Step 1 - Select data for modeling(training data & validation data
X_train = train.drop(['Band1','Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12', \
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13', \
           'insitu-TED0.05','insitu-TED0.1','insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0', \
           'insitu-TED5.0','insitu-PA','insitu-PS','Year','Month','Day','Hour','Minute','YearMonthDayHourMinute', \
           'STN','Lon','Lat','isitu-LST','insitu-TA'], axis=1)
X_test = val.drop(['Band1','Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12', \
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13', \
           'insitu-TED0.05','insitu-TED0.1','insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0', \
           'insitu-TED5.0','insitu-PA','insitu-PS','Year','Month','Day','Hour','Minute','YearMonthDayHourMinute', \
           'STN','Lon','Lat','isitu-LST','insitu-TA'], axis=1)

y_train=train[['isitu-LST', 'insitu-TA']].values
y_test=val[['isitu-LST', 'insitu-TA']].values

X_train
# Out:
#          GK2A-LST    SolarZA    SateZA      ESR  Height  LandType  insitu-HM  \
# 0      -999.00000  162.63634  44.52481 -9.38141   17.53         2       30.3
# 1      -999.00000  162.17793  44.41427 -9.36082  155.48         2       64.1
# 2      -999.00000  162.27711  44.13104 -9.36664  115.62         2       58.4
# 3      -999.00000  162.14729  44.12316 -9.36060   30.59         2       52.8
# 4        -9.38000  162.57755  44.12761 -9.38050   75.82         3       66.0
# ...           ...        ...       ...      ...     ...       ...        ...
# 447705   19.20999  120.35766  40.87855 -4.18556   39.64         2       96.9
# 447706   20.35001  120.38888  41.10588 -4.21799   16.78         2       93.5
# 447707   14.64999  118.81387  42.79873 -3.99159   40.35         2       98.3
# 447708 -999.00000  117.67587  44.18884 -3.84460  140.37         2       95.9
# 447709   21.26999  121.95049  38.90221 -4.38410  141.84         2       89.8
#
#         insitu-TD  insitu-TG  mean_6_23  mean_34_37  mean_38_39  mean_40_42  \
# 0           -17.7       -4.2   0.422121    0.000000    0.000000    0.000000
# 1           -14.5       -7.9  -0.391234    0.000000    0.000000    0.000000
# 2           -14.7       -7.4  -0.355405    0.000000    0.000000    0.000000
# 3           -15.4       -6.5  -0.332510    0.000000    0.000000    0.000000
# 4           -14.3      -14.1  -0.188191   -1.022277   -0.499305    0.114355
# ...           ...        ...        ...         ...         ...         ...
# 447705       20.0       19.4   0.000385    1.107697    1.107273    0.000000
# 447706       18.7     -999.0   0.071010    1.472452    1.488681    0.000000
# 447707       21.6       21.9  -0.144802    1.049685    1.210674    0.000000
# 447708       20.1       19.2  -0.365471    0.726721    0.740235    0.000000
# 447709       20.2       21.4   0.154993    1.010960    1.339413    0.000000
#
#         mean_43_44
# 0         0.868476
# 1         1.114533
# 2         1.315872
# 3         1.666385
# 4         1.402172
# ...            ...
# 447705    0.209894
# 447706    0.000000
# 447707    0.000000
# 447708    0.000000
# 447709    0.000000
#
# [8202668 rows x 14 columns]

# %%
X_test
# Out:
#          GK2A-LST    SolarZA    SateZA      ESR  Height  LandType  insitu-HM  \
# 0      -999.00000  132.65269  44.52481 -6.38871   17.53         2       97.3
# 1      -999.00000  132.82147  44.16866 -6.41119   95.78         3       98.5
# 2      -999.00000  132.53152  44.41427 -6.37791  155.48         2      100.0
# 3        13.45001  132.73465  44.13104 -6.40288  115.62         2       99.9
# 4      -999.00000  132.69038  44.12316 -6.39848   30.59         2       99.8
# ...           ...        ...       ...      ...     ...       ...        ...
# 432625   -9.10999  162.38597  41.92041 -8.86355   15.12         2       82.1
# 432626   -9.66000  162.89288  42.59904 -8.93360   88.62         2       40.1
# 432627   -7.60999  162.98303  40.87855 -8.88743   39.64         2       53.4
# 432628 -999.00000  163.56012  41.10588 -8.94638   16.78         2       36.2
# 432629 -999.00000  163.77446  38.90221 -8.90444  141.84         2       74.7
#
#         insitu-TD  insitu-TG  mean_6_23  mean_34_37  mean_38_39  mean_40_42  \
# 0            16.9       17.8  -0.733944    0.000000    0.000000    0.000000
# 1            17.5       17.5  -0.696051   -0.914975    0.447435    0.341129
# 2            17.1       17.1  -0.279810    0.000000    0.000000    0.000000
# 3            17.7       18.1  -0.195837    0.000000    0.000000    0.000000
# 4            17.7       18.0  -0.370219    0.000000    0.000000    0.000000
# ...           ...        ...        ...         ...         ...         ...
# 432625      -10.7       -9.7  -0.787369   -1.417396   -1.534663    0.000000
# 432626      -17.3       -8.5  -0.672741   -1.492066   -1.894582    0.000000
# 432627      -11.7       -4.8  -0.684352   -0.847900   -0.716603    0.000000
# 432628      -15.7     -999.0  -2.065335   -1.364155   -0.756098    0.000000
# 432629       -0.9        1.4  -0.805391    0.495546    1.334551    0.000000
#
#         mean_43_44
# 0         0.508451
# 1        -0.179931
# 2        -0.365214
# 3        -0.290579
# 4         0.015434
# ...            ...
# 432625    0.000000
# 432626    1.185870
# 432627    1.525860
# 432628    0.000000
# 432629    0.000000
#
# [1780159 rows x 14 columns]

# %%
##### Step 2 - Create training and testing samples
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


##### Step 3 - Specify the structure of a neural network
model2 = Sequential(name="Model-with-Two-Inputs")
model2.add(Input(shape=(len(X_train.columns),), name='Input-Layer'))
model2.add(Dense(len(X_train.columns), activation='relu', name='Hidden-Layer1'))
model2.add(Dense(len(X_train.columns), activation='relu', name='Hidden-Layer2'))
model2.add(Dense(len(X_train.columns), activation='relu', name='Hidden-Layer3'))
model2.add(Dense(2, activation='relu', name='Output-Layer'))


##### Step 4 - Compile the keras model
model2.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse'],
              loss_weights=None,
              weighted_metrics=None,
              run_eagerly=None, 
              steps_per_execution=None 
             )

model2.summary()
# Out:
# Model: "Model-with-Two-Inputs"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-Layer1 (Dense)       (None, 14)                210
#
#  Hidden-Layer2 (Dense)       (None, 14)                210
#
#  Hidden-Layer3 (Dense)       (None, 14)                210
#
#  Output-Layer (Dense)        (None, 2)                 30
#
# =================================================================
# Total params: 660
# Trainable params: 660
# Non-trainable params: 0
# _________________________________________________________________

# %%
cd C:\weather
# Out:
# C:\weather

# %%
os.getcwd()
# Out:
# 'C:\\weather'

# %%
##### Step 5 - Fit keras model on the dataset

# Set Directory
save_dir = os.path.join(os.getcwd(),'save')

model_name = 'ffnn_v2.{epoch:02d}.h5' 
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)


checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_mse',
                             verbose=1,
                             save_best_only=True)

callbacks = checkpoint

# %%
hist = model2.fit(X_train.to_numpy(),       # input data
          y_train,                 # target data
          batch_size=32,    
          epochs=100,         # 늘려야 할 부분     
          validation_data=(X_test, y_test),
          shuffle=True,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 256292/256334 [============================>.] - ETA: 0s - loss: 14.2260 - mse: 14.2260
# Epoch 1: val_mse improved from inf to 3.38234, saving model to C:\weather\save\ffnn_v2.01.h5
# 256334/256334 [==============================] - 146s 567us/step - loss: 14.2244 - mse: 14.2244 - val_loss: 3.3823 - val_mse: 3.3823
# Epoch 2/100
# 256293/256334 [============================>.] - ETA: 0s - loss: 4.3877 - mse: 4.3877
# Epoch 2: val_mse did not improve from 3.38234
# 256334/256334 [==============================] - 147s 573us/step - loss: 4.3878 - mse: 4.3878 - val_loss: 3.4990 - val_mse: 3.4990
# Epoch 3/100
# 256244/256334 [============================>.] - ETA: 0s - loss: 4.2247 - mse: 4.2247
# Epoch 3: val_mse improved from 3.38234 to 3.19699, saving model to C:\weather\save\ffnn_v2.03.h5
# 256334/256334 [==============================] - 147s 575us/step - loss: 4.2247 - mse: 4.2247 - val_loss: 3.1970 - val_mse: 3.1970
# Epoch 4/100
# 256297/256334 [============================>.] - ETA: 0s - loss: 4.1511 - mse: 4.1511
# Epoch 4: val_mse improved from 3.19699 to 3.14074, saving model to C:\weather\save\ffnn_v2.04.h5
# 256334/256334 [==============================] - 149s 580us/step - loss: 4.1512 - mse: 4.1512 - val_loss: 3.1407 - val_mse: 3.1407
# Epoch 5/100
# 256301/256334 [============================>.] - ETA: 0s - loss: 4.1182 - mse: 4.1182
# Epoch 5: val_mse improved from 3.14074 to 3.09688, saving model to C:\weather\save\ffnn_v2.05.h5
# 256334/256334 [==============================] - 145s 565us/step - loss: 4.1181 - mse: 4.1181 - val_loss: 3.0969 - val_mse: 3.0969
# Epoch 6/100
# 256309/256334 [============================>.] - ETA: 0s - loss: 4.0928 - mse: 4.0928
# Epoch 6: val_mse improved from 3.09688 to 2.99328, saving model to C:\weather\save\ffnn_v2.06.h5
# 256334/256334 [==============================] - 144s 563us/step - loss: 4.0928 - mse: 4.0928 - val_loss: 2.9933 - val_mse: 2.9933
# Epoch 7/100
# 256327/256334 [============================>.] - ETA: 0s - loss: 4.0779 - mse: 4.0779
# Epoch 7: val_mse did not improve from 2.99328
# 256334/256334 [==============================] - 145s 566us/step - loss: 4.0779 - mse: 4.0779 - val_loss: 3.1501 - val_mse: 3.1501
# Epoch 8/100
# 256259/256334 [============================>.] - ETA: 0s - loss: 4.0583 - mse: 4.0583
# Epoch 8: val_mse did not improve from 2.99328
# 256334/256334 [==============================] - 144s 563us/step - loss: 4.0583 - mse: 4.0583 - val_loss: 3.0381 - val_mse: 3.0381
# Epoch 9/100
# 256240/256334 [============================>.] - ETA: 0s - loss: 4.0537 - mse: 4.0537
# Epoch 9: val_mse improved from 2.99328 to 2.94381, saving model to C:\weather\save\ffnn_v2.09.h5
# 256334/256334 [==============================] - 143s 558us/step - loss: 4.0537 - mse: 4.0537 - val_loss: 2.9438 - val_mse: 2.9438
# Epoch 10/100
# 256240/256334 [============================>.] - ETA: 0s - loss: 4.0500 - mse: 4.0500
# Epoch 10: val_mse did not improve from 2.94381
# 256334/256334 [==============================] - 142s 555us/step - loss: 4.0500 - mse: 4.0500 - val_loss: 3.1665 - val_mse: 3.1665
# Epoch 11/100
# 256334/256334 [==============================] - ETA: 0s - loss: 4.0440 - mse: 4.0440
# Epoch 11: val_mse did not improve from 2.94381
# 256334/256334 [==============================] - 141s 550us/step - loss: 4.0440 - mse: 4.0440 - val_loss: 3.5019 - val_mse: 3.5019
# Epoch 12/100
# 256255/256334 [============================>.] - ETA: 0s - loss: 4.0324 - mse: 4.0324
# Epoch 12: val_mse did not improve from 2.94381
# 256334/256334 [==============================] - 144s 561us/step - loss: 4.0324 - mse: 4.0324 - val_loss: 3.0420 - val_mse: 3.0420
# Epoch 13/100
# 256325/256334 [============================>.] - ETA: 0s - loss: 4.0357 - mse: 4.0357
# Epoch 13: val_mse improved from 2.94381 to 2.92563, saving model to C:\weather\save\ffnn_v2.13.h5
# 256334/256334 [==============================] - 147s 572us/step - loss: 4.0357 - mse: 4.0357 - val_loss: 2.9256 - val_mse: 2.9256
# Epoch 14/100
# 256329/256334 [============================>.] - ETA: 0s - loss: 4.0196 - mse: 4.0196
# Epoch 14: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 146s 568us/step - loss: 4.0196 - mse: 4.0196 - val_loss: 3.0258 - val_mse: 3.0258
# Epoch 15/100
# 256299/256334 [============================>.] - ETA: 0s - loss: 4.0117 - mse: 4.0117
# Epoch 15: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 151s 587us/step - loss: 4.0117 - mse: 4.0117 - val_loss: 2.9443 - val_mse: 2.9443
# Epoch 16/100
# 256293/256334 [============================>.] - ETA: 0s - loss: 4.0068 - mse: 4.0068
# Epoch 16: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 145s 565us/step - loss: 4.0069 - mse: 4.0069 - val_loss: 3.0024 - val_mse: 3.0024
# Epoch 17/100
# 256292/256334 [============================>.] - ETA: 0s - loss: 4.0001 - mse: 4.0001
# Epoch 17: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 146s 569us/step - loss: 4.0002 - mse: 4.0002 - val_loss: 3.1624 - val_mse: 3.1624
# Epoch 18/100
# 256285/256334 [============================>.] - ETA: 0s - loss: 3.9973 - mse: 3.9973
# Epoch 18: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 147s 574us/step - loss: 3.9973 - mse: 3.9973 - val_loss: 2.9761 - val_mse: 2.9761
# Epoch 19/100
# 256305/256334 [============================>.] - ETA: 0s - loss: 3.9974 - mse: 3.9974
# Epoch 19: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 144s 563us/step - loss: 3.9975 - mse: 3.9975 - val_loss: 3.1000 - val_mse: 3.1000
# Epoch 20/100
# 256287/256334 [============================>.] - ETA: 0s - loss: 3.9930 - mse: 3.9930
# Epoch 20: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 143s 558us/step - loss: 3.9929 - mse: 3.9929 - val_loss: 3.0661 - val_mse: 3.0661
# Epoch 21/100
# 256318/256334 [============================>.] - ETA: 0s - loss: 3.9843 - mse: 3.9843
# Epoch 21: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 147s 575us/step - loss: 3.9843 - mse: 3.9843 - val_loss: 2.9937 - val_mse: 2.9937
# Epoch 22/100
# 256328/256334 [============================>.] - ETA: 0s - loss: 3.9818 - mse: 3.9818
# Epoch 22: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 146s 570us/step - loss: 3.9818 - mse: 3.9818 - val_loss: 2.9758 - val_mse: 2.9758
# Epoch 23/100
# 256277/256334 [============================>.] - ETA: 0s - loss: 3.9838 - mse: 3.9838
# Epoch 23: val_mse did not improve from 2.92563
# 256334/256334 [==============================] - 145s 568us/step - loss: 3.9839 - mse: 3.9839 - val_loss: 2.9707 - val_mse: 2.9707
# Epoch 24/100
# 256321/256334 [============================>.] - ETA: 0s - loss: 3.9814 - mse: 3.9814
# Epoch 24: val_mse improved from 2.92563 to 2.90008, saving model to C:\weather\save\ffnn_v2.24.h5
# 256334/256334 [==============================] - 147s 575us/step - loss: 3.9814 - mse: 3.9814 - val_loss: 2.9001 - val_mse: 2.9001
# Epoch 25/100
# 256318/256334 [============================>.] - ETA: 0s - loss: 3.9785 - mse: 3.9785
# Epoch 25: val_mse did not improve from 2.90008
# 256334/256334 [==============================] - 145s 565us/step - loss: 3.9785 - mse: 3.9785 - val_loss: 3.0502 - val_mse: 3.0502
# Epoch 26/100
# 256332/256334 [============================>.] - ETA: 0s - loss: 3.9735 - mse: 3.9735
# Epoch 26: val_mse did not improve from 2.90008
# 256334/256334 [==============================] - 143s 557us/step - loss: 3.9735 - mse: 3.9735 - val_loss: 2.9837 - val_mse: 2.9837
# Epoch 27/100
# 256250/256334 [============================>.] - ETA: 0s - loss: 3.9718 - mse: 3.9718
# Epoch 27: val_mse did not improve from 2.90008
# 256334/256334 [==============================] - 140s 545us/step - loss: 3.9717 - mse: 3.9717 - val_loss: 3.2423 - val_mse: 3.2423
# Epoch 28/100
# 256291/256334 [============================>.] - ETA: 0s - loss: 3.9740 - mse: 3.9740
# Epoch 28: val_mse improved from 2.90008 to 2.89083, saving model to C:\weather\save\ffnn_v2.28.h5
# 256334/256334 [==============================] - 142s 553us/step - loss: 3.9739 - mse: 3.9739 - val_loss: 2.8908 - val_mse: 2.8908
# Epoch 29/100
# 256242/256334 [============================>.] - ETA: 0s - loss: 3.9742 - mse: 3.9742
# Epoch 29: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 138s 538us/step - loss: 3.9741 - mse: 3.9741 - val_loss: 2.9406 - val_mse: 2.9406
# Epoch 30/100
# 256261/256334 [============================>.] - ETA: 0s - loss: 3.9695 - mse: 3.9695
# Epoch 30: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 137s 534us/step - loss: 3.9695 - mse: 3.9695 - val_loss: 2.9255 - val_mse: 2.9255
# Epoch 31/100
# 256250/256334 [============================>.] - ETA: 0s - loss: 3.9687 - mse: 3.9687
# Epoch 31: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 141s 550us/step - loss: 3.9688 - mse: 3.9688 - val_loss: 3.1303 - val_mse: 3.1303
# Epoch 32/100
# 256274/256334 [============================>.] - ETA: 0s - loss: 3.9813 - mse: 3.9813
# Epoch 32: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 143s 557us/step - loss: 3.9813 - mse: 3.9813 - val_loss: 3.0047 - val_mse: 3.0047
# Epoch 33/100
# 256266/256334 [============================>.] - ETA: 0s - loss: 3.9675 - mse: 3.9675
# Epoch 33: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 142s 552us/step - loss: 3.9674 - mse: 3.9674 - val_loss: 3.1068 - val_mse: 3.1068
# Epoch 34/100
# 256285/256334 [============================>.] - ETA: 0s - loss: 3.9676 - mse: 3.9676
# Epoch 34: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 141s 548us/step - loss: 3.9676 - mse: 3.9676 - val_loss: 3.0998 - val_mse: 3.0998
# Epoch 35/100
# 256333/256334 [============================>.] - ETA: 0s - loss: 3.9644 - mse: 3.9644
# Epoch 35: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 140s 545us/step - loss: 3.9644 - mse: 3.9644 - val_loss: 2.9910 - val_mse: 2.9910
# Epoch 36/100
# 256245/256334 [============================>.] - ETA: 0s - loss: 3.9682 - mse: 3.9682
# Epoch 36: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9683 - mse: 3.9683 - val_loss: 2.9046 - val_mse: 2.9046
# Epoch 37/100
# 256296/256334 [============================>.] - ETA: 0s - loss: 3.9673 - mse: 3.9673
# Epoch 37: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 142s 554us/step - loss: 3.9674 - mse: 3.9674 - val_loss: 2.9238 - val_mse: 2.9238
# Epoch 38/100
# 256240/256334 [============================>.] - ETA: 0s - loss: 3.9631 - mse: 3.9631
# Epoch 38: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 146s 569us/step - loss: 3.9631 - mse: 3.9631 - val_loss: 2.9718 - val_mse: 2.9718
# Epoch 39/100
# 256284/256334 [============================>.] - ETA: 0s - loss: 3.9615 - mse: 3.9615
# Epoch 39: val_mse did not improve from 2.89083
# 256334/256334 [==============================] - 144s 561us/step - loss: 3.9614 - mse: 3.9614 - val_loss: 2.9577 - val_mse: 2.9577
# Epoch 40/100
# 256287/256334 [============================>.] - ETA: 0s - loss: 3.9620 - mse: 3.9620
# Epoch 40: val_mse improved from 2.89083 to 2.88881, saving model to C:\weather\save\ffnn_v2.40.h5
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9620 - mse: 3.9620 - val_loss: 2.8888 - val_mse: 2.8888
# Epoch 41/100
# 256274/256334 [============================>.] - ETA: 0s - loss: 3.9596 - mse: 3.9596
# Epoch 41: val_mse improved from 2.88881 to 2.88067, saving model to C:\weather\save\ffnn_v2.41.h5
# 256334/256334 [==============================] - 140s 545us/step - loss: 3.9595 - mse: 3.9595 - val_loss: 2.8807 - val_mse: 2.8807
# Epoch 42/100
# 256297/256334 [============================>.] - ETA: 0s - loss: 3.9602 - mse: 3.9602
# Epoch 42: val_mse did not improve from 2.88067
# 256334/256334 [==============================] - 141s 551us/step - loss: 3.9603 - mse: 3.9603 - val_loss: 3.0685 - val_mse: 3.0685
# Epoch 43/100
# 256230/256334 [============================>.] - ETA: 0s - loss: 3.9614 - mse: 3.9614
# Epoch 43: val_mse did not improve from 2.88067
# 256334/256334 [==============================] - 138s 540us/step - loss: 3.9613 - mse: 3.9613 - val_loss: 2.8935 - val_mse: 2.8935
# Epoch 44/100
# 256268/256334 [============================>.] - ETA: 0s - loss: 3.9584 - mse: 3.9584
# Epoch 44: val_mse did not improve from 2.88067
# 256334/256334 [==============================] - 141s 551us/step - loss: 3.9585 - mse: 3.9585 - val_loss: 2.8812 - val_mse: 2.8812
# Epoch 45/100
# 256265/256334 [============================>.] - ETA: 0s - loss: 3.9571 - mse: 3.9571
# Epoch 45: val_mse did not improve from 2.88067
# 256334/256334 [==============================] - 146s 568us/step - loss: 3.9571 - mse: 3.9571 - val_loss: 3.0892 - val_mse: 3.0892
# Epoch 46/100
# 256310/256334 [============================>.] - ETA: 0s - loss: 3.9587 - mse: 3.9587
# Epoch 46: val_mse improved from 2.88067 to 2.81329, saving model to C:\weather\save\ffnn_v2.46.h5
# 256334/256334 [==============================] - 148s 576us/step - loss: 3.9587 - mse: 3.9587 - val_loss: 2.8133 - val_mse: 2.8133
# Epoch 47/100
# 256324/256334 [============================>.] - ETA: 0s - loss: 3.9581 - mse: 3.9581
# Epoch 47: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 144s 562us/step - loss: 3.9581 - mse: 3.9581 - val_loss: 2.9024 - val_mse: 2.9024
# Epoch 48/100
# 256290/256334 [============================>.] - ETA: 0s - loss: 3.9537 - mse: 3.9537
# Epoch 48: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 143s 557us/step - loss: 3.9537 - mse: 3.9537 - val_loss: 2.9852 - val_mse: 2.9852
# Epoch 49/100
# 256286/256334 [============================>.] - ETA: 0s - loss: 3.9546 - mse: 3.9546
# Epoch 49: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 552us/step - loss: 3.9547 - mse: 3.9547 - val_loss: 2.8987 - val_mse: 2.8987
# Epoch 50/100
# 256306/256334 [============================>.] - ETA: 0s - loss: 3.9553 - mse: 3.9553
# Epoch 50: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 143s 557us/step - loss: 3.9553 - mse: 3.9553 - val_loss: 2.8587 - val_mse: 2.8587
# Epoch 51/100
# 256241/256334 [============================>.] - ETA: 0s - loss: 3.9542 - mse: 3.9542
# Epoch 51: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 555us/step - loss: 3.9542 - mse: 3.9542 - val_loss: 3.1001 - val_mse: 3.1001
# Epoch 52/100
# 256333/256334 [============================>.] - ETA: 0s - loss: 3.9576 - mse: 3.9576
# Epoch 52: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 146s 568us/step - loss: 3.9576 - mse: 3.9576 - val_loss: 3.3846 - val_mse: 3.3846
# Epoch 53/100
# 256257/256334 [============================>.] - ETA: 0s - loss: 3.9529 - mse: 3.9529
# Epoch 53: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 553us/step - loss: 3.9529 - mse: 3.9529 - val_loss: 3.1157 - val_mse: 3.1157
# Epoch 54/100
# 256250/256334 [============================>.] - ETA: 0s - loss: 3.9523 - mse: 3.9523
# Epoch 54: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 139s 541us/step - loss: 3.9523 - mse: 3.9523 - val_loss: 3.0043 - val_mse: 3.0043
# Epoch 55/100
# 256277/256334 [============================>.] - ETA: 0s - loss: 3.9588 - mse: 3.9588
# Epoch 55: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 544us/step - loss: 3.9588 - mse: 3.9588 - val_loss: 3.1128 - val_mse: 3.1128
# Epoch 56/100
# 256248/256334 [============================>.] - ETA: 0s - loss: 3.9511 - mse: 3.9511
# Epoch 56: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 549us/step - loss: 3.9512 - mse: 3.9512 - val_loss: 3.2491 - val_mse: 3.2491
# Epoch 57/100
# 256326/256334 [============================>.] - ETA: 0s - loss: 3.9829 - mse: 3.9829
# Epoch 57: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 139s 543us/step - loss: 3.9829 - mse: 3.9829 - val_loss: 3.0661 - val_mse: 3.0661
# Epoch 58/100
# 256248/256334 [============================>.] - ETA: 0s - loss: 4.0092 - mse: 4.0092
# Epoch 58: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 139s 541us/step - loss: 4.0091 - mse: 4.0091 - val_loss: 3.1950 - val_mse: 3.1950
# Epoch 59/100
# 256334/256334 [==============================] - ETA: 0s - loss: 3.9855 - mse: 3.9855
# Epoch 59: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 551us/step - loss: 3.9855 - mse: 3.9855 - val_loss: 2.9365 - val_mse: 2.9365
# Epoch 60/100
# 256302/256334 [============================>.] - ETA: 0s - loss: 3.9746 - mse: 3.9746
# Epoch 60: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 554us/step - loss: 3.9746 - mse: 3.9746 - val_loss: 2.9267 - val_mse: 2.9267
# Epoch 61/100
# 256239/256334 [============================>.] - ETA: 0s - loss: 3.9725 - mse: 3.9725
# Epoch 61: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 139s 544us/step - loss: 3.9725 - mse: 3.9725 - val_loss: 2.9913 - val_mse: 2.9913
# Epoch 62/100
# 256259/256334 [============================>.] - ETA: 0s - loss: 3.9791 - mse: 3.9791
# Epoch 62: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 550us/step - loss: 3.9791 - mse: 3.9791 - val_loss: 2.9516 - val_mse: 2.9516
# Epoch 63/100
# 256249/256334 [============================>.] - ETA: 0s - loss: 3.9755 - mse: 3.9755
# Epoch 63: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 546us/step - loss: 3.9755 - mse: 3.9755 - val_loss: 3.1172 - val_mse: 3.1172
# Epoch 64/100
# 256240/256334 [============================>.] - ETA: 0s - loss: 3.9764 - mse: 3.9764
# Epoch 64: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9766 - mse: 3.9766 - val_loss: 3.0476 - val_mse: 3.0476
# Epoch 65/100
# 256234/256334 [============================>.] - ETA: 0s - loss: 3.9827 - mse: 3.9827
# Epoch 65: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 549us/step - loss: 3.9826 - mse: 3.9826 - val_loss: 3.0120 - val_mse: 3.0120
# Epoch 66/100
# 256238/256334 [============================>.] - ETA: 0s - loss: 3.9903 - mse: 3.9903
# Epoch 66: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 143s 558us/step - loss: 3.9903 - mse: 3.9903 - val_loss: 3.0789 - val_mse: 3.0789
# Epoch 67/100
# 256229/256334 [============================>.] - ETA: 0s - loss: 3.9890 - mse: 3.9890
# Epoch 67: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9888 - mse: 3.9888 - val_loss: 3.1680 - val_mse: 3.1680
# Epoch 68/100
# 256288/256334 [============================>.] - ETA: 0s - loss: 3.9752 - mse: 3.9752
# Epoch 68: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 554us/step - loss: 3.9752 - mse: 3.9752 - val_loss: 3.0010 - val_mse: 3.0010
# Epoch 69/100
# 256259/256334 [============================>.] - ETA: 0s - loss: 3.9710 - mse: 3.9710
# Epoch 69: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9710 - mse: 3.9710 - val_loss: 2.9622 - val_mse: 2.9622
# Epoch 70/100
# 256278/256334 [============================>.] - ETA: 0s - loss: 3.9655 - mse: 3.9655
# Epoch 70: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 553us/step - loss: 3.9655 - mse: 3.9655 - val_loss: 3.0024 - val_mse: 3.0024
# Epoch 71/100
# 256237/256334 [============================>.] - ETA: 0s - loss: 3.9629 - mse: 3.9629
# Epoch 71: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 545us/step - loss: 3.9631 - mse: 3.9631 - val_loss: 2.9324 - val_mse: 2.9324
# Epoch 72/100
# 256240/256334 [============================>.] - ETA: 0s - loss: 3.9662 - mse: 3.9662
# Epoch 72: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 551us/step - loss: 3.9663 - mse: 3.9663 - val_loss: 3.0024 - val_mse: 3.0024
# Epoch 73/100
# 256267/256334 [============================>.] - ETA: 0s - loss: 3.9598 - mse: 3.9598
# Epoch 73: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 548us/step - loss: 3.9598 - mse: 3.9598 - val_loss: 3.0269 - val_mse: 3.0269
# Epoch 74/100
# 256232/256334 [============================>.] - ETA: 0s - loss: 3.9591 - mse: 3.9591
# Epoch 74: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 144s 560us/step - loss: 3.9591 - mse: 3.9591 - val_loss: 3.0088 - val_mse: 3.0088
# Epoch 75/100
# 256245/256334 [============================>.] - ETA: 0s - loss: 3.9630 - mse: 3.9630
# Epoch 75: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 144s 561us/step - loss: 3.9630 - mse: 3.9630 - val_loss: 2.9000 - val_mse: 2.9000
# Epoch 76/100
# 256314/256334 [============================>.] - ETA: 0s - loss: 3.9595 - mse: 3.9595
# Epoch 76: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 144s 563us/step - loss: 3.9594 - mse: 3.9594 - val_loss: 2.8980 - val_mse: 2.8980
# Epoch 77/100
# 256325/256334 [============================>.] - ETA: 0s - loss: 3.9630 - mse: 3.9630
# Epoch 77: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 548us/step - loss: 3.9630 - mse: 3.9630 - val_loss: 2.9679 - val_mse: 2.9679
# Epoch 78/100
# 256255/256334 [============================>.] - ETA: 0s - loss: 3.9605 - mse: 3.9605
# Epoch 78: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9604 - mse: 3.9604 - val_loss: 2.8943 - val_mse: 2.8943
# Epoch 79/100
# 256248/256334 [============================>.] - ETA: 0s - loss: 3.9528 - mse: 3.9528
# Epoch 79: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 140s 547us/step - loss: 3.9528 - mse: 3.9528 - val_loss: 3.2887 - val_mse: 3.2887
# Epoch 80/100
# 256273/256334 [============================>.] - ETA: 0s - loss: 3.9542 - mse: 3.9542
# Epoch 80: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 550us/step - loss: 3.9542 - mse: 3.9542 - val_loss: 2.9373 - val_mse: 2.9373
# Epoch 81/100
# 256252/256334 [============================>.] - ETA: 0s - loss: 3.9543 - mse: 3.9543
# Epoch 81: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 554us/step - loss: 3.9542 - mse: 3.9542 - val_loss: 2.9726 - val_mse: 2.9726
# Epoch 82/100
# 256299/256334 [============================>.] - ETA: 0s - loss: 3.9508 - mse: 3.9508
# Epoch 82: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 144s 561us/step - loss: 3.9508 - mse: 3.9508 - val_loss: 3.2059 - val_mse: 3.2059
# Epoch 83/100
# 256276/256334 [============================>.] - ETA: 0s - loss: 3.9497 - mse: 3.9497
# Epoch 83: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 549us/step - loss: 3.9497 - mse: 3.9497 - val_loss: 3.1905 - val_mse: 3.1905
# Epoch 84/100
# 256273/256334 [============================>.] - ETA: 0s - loss: 3.9464 - mse: 3.9464
# Epoch 84: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 142s 554us/step - loss: 3.9465 - mse: 3.9465 - val_loss: 3.0273 - val_mse: 3.0273
# Epoch 85/100
# 256329/256334 [============================>.] - ETA: 0s - loss: 4.0753 - mse: 4.0753
# Epoch 85: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 143s 556us/step - loss: 4.0753 - mse: 4.0753 - val_loss: 3.2208 - val_mse: 3.2208
# Epoch 86/100
# 256313/256334 [============================>.] - ETA: 0s - loss: 3.9506 - mse: 3.9506
# Epoch 86: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 141s 549us/step - loss: 3.9506 - mse: 3.9506 - val_loss: 3.0331 - val_mse: 3.0331
# Epoch 87/100
# 256287/256334 [============================>.] - ETA: 0s - loss: 3.9448 - mse: 3.9448
# Epoch 87: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 134s 521us/step - loss: 3.9448 - mse: 3.9448 - val_loss: 3.0696 - val_mse: 3.0696
# Epoch 88/100
# 256264/256334 [============================>.] - ETA: 0s - loss: 3.9415 - mse: 3.9415
# Epoch 88: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 137s 533us/step - loss: 3.9415 - mse: 3.9415 - val_loss: 3.5223 - val_mse: 3.5223
# Epoch 89/100
# 256322/256334 [============================>.] - ETA: 0s - loss: 3.9401 - mse: 3.9401
# Epoch 89: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 136s 530us/step - loss: 3.9402 - mse: 3.9402 - val_loss: 2.8820 - val_mse: 2.8820
# Epoch 90/100
# 256239/256334 [============================>.] - ETA: 0s - loss: 3.9409 - mse: 3.9409
# Epoch 90: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 136s 530us/step - loss: 3.9408 - mse: 3.9408 - val_loss: 2.9087 - val_mse: 2.9087
# Epoch 91/100
# 256303/256334 [============================>.] - ETA: 0s - loss: 3.9394 - mse: 3.9394
# Epoch 91: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 136s 529us/step - loss: 3.9394 - mse: 3.9394 - val_loss: 3.0336 - val_mse: 3.0336
# Epoch 92/100
# 256308/256334 [============================>.] - ETA: 0s - loss: 3.9396 - mse: 3.9396
# Epoch 92: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 136s 531us/step - loss: 3.9396 - mse: 3.9396 - val_loss: 2.8933 - val_mse: 2.8933
# Epoch 93/100
# 256276/256334 [============================>.] - ETA: 0s - loss: 3.9377 - mse: 3.9377
# Epoch 93: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 136s 532us/step - loss: 3.9377 - mse: 3.9377 - val_loss: 2.9049 - val_mse: 2.9049
# Epoch 94/100
# 256292/256334 [============================>.] - ETA: 0s - loss: 3.9390 - mse: 3.9390
# Epoch 94: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 134s 523us/step - loss: 3.9390 - mse: 3.9390 - val_loss: 2.9508 - val_mse: 2.9508
# Epoch 95/100
# 256334/256334 [==============================] - ETA: 0s - loss: 3.9454 - mse: 3.9454
# Epoch 95: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 135s 526us/step - loss: 3.9454 - mse: 3.9454 - val_loss: 2.9463 - val_mse: 2.9463
# Epoch 96/100
# 256308/256334 [============================>.] - ETA: 0s - loss: 3.9471 - mse: 3.9471
# Epoch 96: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 132s 513us/step - loss: 3.9472 - mse: 3.9472 - val_loss: 3.1445 - val_mse: 3.1445
# Epoch 97/100
# 256265/256334 [============================>.] - ETA: 0s - loss: 3.9386 - mse: 3.9386
# Epoch 97: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 134s 522us/step - loss: 3.9387 - mse: 3.9387 - val_loss: 3.0558 - val_mse: 3.0558
# Epoch 98/100
# 256283/256334 [============================>.] - ETA: 0s - loss: 3.9408 - mse: 3.9408
# Epoch 98: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 133s 520us/step - loss: 3.9408 - mse: 3.9408 - val_loss: 3.1129 - val_mse: 3.1129
# Epoch 99/100
# 256238/256334 [============================>.] - ETA: 0s - loss: 3.9447 - mse: 3.9447
# Epoch 99: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 137s 534us/step - loss: 3.9446 - mse: 3.9446 - val_loss: 2.8938 - val_mse: 2.8938
# Epoch 100/100
# 256303/256334 [============================>.] - ETA: 0s - loss: 3.9411 - mse: 3.9411
# Epoch 100: val_mse did not improve from 2.81329
# 256334/256334 [==============================] - 135s 525us/step - loss: 3.9412 - mse: 3.9412 - val_loss: 2.9500 - val_mse: 2.9500

# %%
model2.save('ffnn_v2.h5')

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(hist.history) 

# or save to csv: 
hist_csv_file = 'ffnn_v2_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
hh = pd.read_csv('ffnn_v2_history.csv')
hh
# Out:
#     Unnamed: 0       loss        mse  val_loss   val_mse
# 0            0  14.224367  14.224367  3.382335  3.382335
# 1            1   4.387770   4.387770  3.499034  3.499034
# 2            2   4.224678   4.224678  3.196992  3.196992
# 3            3   4.151183   4.151183  3.140743  3.140743
# 4            4   4.118145   4.118145  3.096875  3.096875
# ..         ...        ...        ...       ...       ...
# 95          95   3.947212   3.947212  3.144511  3.144511
# 96          96   3.938669   3.938669  3.055780  3.055780
# 97          97   3.940818   3.940818  3.112876  3.112876
# 98          98   3.944611   3.944611  2.893771  2.893771
# 99          99   3.941161   3.941161  2.949963  2.949963
#
# [100 rows x 5 columns]

# %% [markdown]
# # 시각화

# %% [markdown]
# Loss

# %%
def Plot_history(history):
  plt.subplot(211)
  plt.plot(hist.history['loss'], color = 'b', label = 'train')
  plt.plot(hist.history['val_loss'], color = 'g', label = 'test')
  plt.ylabel('Loss')
  plt.legend()

#   plt.subplot(212)
#   plt.plot(hist.history['mse'], color = 'r', label = 'train')
#   plt.plot(hist.history['val_mse'], color = 'black', label = 'test')
#   plt.xlabel('Epoch')
#   plt.ylabel('mse')
#   plt.legend()
#   plt.show()

# %%
Plot_history(hist)

# %%
scores = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test mse:', scores[1])
# Out:
# Test loss: 2.949962854385376
# Test mse: 2.949962854385376

# %% [markdown]
# LST,TA

# %%
# LST,TA 얼마나 잘 맞췄는지 겹쳐 그래프도 그리기

# %%
pred_te = model2.predict(X_test)
pred_te
# Out:
# 55630/55630 [==============================] - 19s 336us/step
# array([[18.406624  , 17.289558  ],
#        [17.991695  , 17.655924  ],
#        [17.782906  , 16.949745  ],
#        ...,
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.32886124],
#        [ 2.8116007 ,  3.3386846 ]], dtype=float32)

# %%
lst_pr = []
ta_pr = []
for i in range(len(pred_te)):
    lst_pr.append(pred_te[i][0])
    ta_pr.append(pred_te[i][1])

# %%
lst_re = []
ta_re = []
for i in range(len(y_test)):
    lst_re.append(y_test[i][0])
    ta_re.append(y_test[i][1])

# %%
def value_compare():
  plt.subplot(211)
  plt.plot(lst_pr[500:550], color = 'b', label = 'pred')
  plt.plot(lst_re[500:550], color = 'g', label = 'real')
  plt.ylabel('LST')
  plt.legend()

  plt.subplot(212)
  plt.plot(ta_pr[700:750], color = 'r', label = 'pred')
  plt.plot(ta_re[700:750], color = 'black', label = 'real')
  plt.ylabel('TA')
  plt.legend()
  plt.show()

# %%
value_compare()

# %% [markdown]
# # 예측 값 파일에 저장

# %%
test_ = test.drop(['Band1','Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12', \
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13', \
           'insitu-TED0.05','insitu-TED0.1','insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0', \
           'insitu-TED5.0','insitu-PA','insitu-PS','Year','Month','Day','Hour','Minute','YearMonthDayHourMinute', \
           'STN','Lon','Lat'], axis=1)

# %%
pred = model2.predict(test_)
pred
# Out:
# 1704/1704 [==============================] - 1s 354us/step
# array([[21.15091 , 20.950663],
#        [21.39944 , 20.732632],
#        [19.682354, 18.964403],
#        ...,
#        [21.399189, 20.217953],
#        [17.992367, 17.31112 ],
#        [26.326286, 24.25827 ]], dtype=float32)

# %%
submission1 = submission.copy()
submission1
# Out:
#        YearMonthDayHourMinute  STN  isitu-LST  insitu-TA
# 0                202107010030   90        NaN        NaN
# 1                202107010030   93        NaN        NaN
# 2                202107010030   95        NaN        NaN
# 3                202107010030   98        NaN        NaN
# 4                202107010030   99        NaN        NaN
# ...                       ...  ...        ...        ...
# 54498            202108312330  973        NaN        NaN
# 54499            202108312330  974        NaN        NaN
# 54500            202108312330  977        NaN        NaN
# 54501            202108312330  978        NaN        NaN
# 54502            202108312330  980        NaN        NaN
#
# [54503 rows x 4 columns]

# %%
submission1[['isitu-LST', 'insitu-TA']] = pred
submission1
# Out:
#        YearMonthDayHourMinute  STN  isitu-LST  insitu-TA
# 0                202107010030   90  21.150909  20.950663
# 1                202107010030   93  21.399441  20.732632
# 2                202107010030   95  19.682354  18.964403
# 3                202107010030   98  21.043221  19.731483
# 4                202107010030   99  21.432114  20.207371
# ...                       ...  ...        ...        ...
# 54498            202108312330  973  25.623577  24.106720
# 54499            202108312330  974  22.647842  23.341351
# 54500            202108312330  977  21.399189  20.217953
# 54501            202108312330  978  17.992367  17.311119
# 54502            202108312330  980  26.326286  24.258270
#
# [54503 rows x 4 columns]

# %%
cd C:\weather
# Out:
# C:\weather

# %%
submission1.to_csv("ffnn_v2_220224.csv", index = False)    # 접수번호로 저장
