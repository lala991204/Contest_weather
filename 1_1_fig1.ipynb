# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('NA_ratio_uv.csv')
df = df.set_index(df.columns[0])
df = df.drop(['train_num', '검증셋_num', '검증셋_ratio'], axis=1)
df
# Out:
#             train_ratio
# Unnamed: 0
# yyyymmdd       0.000000
# hhnn           0.000000
# stn            0.000000
# lon            0.000000
# lat            0.000000
# uv             0.033697
# band1          0.011438
# band2          0.011438
# band3          0.011438
# band4          0.011438
# band5          0.011438
# band6          0.011438
# band7          0.011442
# band8          0.011438
# band9          0.011438
# band10         0.011438
# band11         0.011438
# band12         0.011438
# band13         0.011438
# band14         0.011438
# band15         0.011438
# band16         0.011438
# solarza        0.000000
# sateza         0.000000
# esr            0.000000
# height         0.000000
# landtype       0.000000

# %%
df.index
# Out:
# Index(['yyyymmdd', 'hhnn', 'stn', 'lon', 'lat', 'uv', 'band1', 'band2',
#        'band3', 'band4', 'band5', 'band6', 'band7', 'band8', 'band9', 'band10',
#        'band11', 'band12', 'band13', 'band14', 'band15', 'band16', 'solarza',
#        'sateza', 'esr', 'height', 'landtype'],
#       dtype='object', name='Unnamed: 0')

# %%
df = df.drop(['band2','band3', 'band4', 'band5', 'band6', 'band7', 'band8', 'band9', 'band10',\
       'band11', 'band12', 'band13', 'band14', 'band15', 'band16'],axis=0)
df = df.rename(index={'band1': 'band1~16'})

# %%
df
# Out:
#             train_ratio
# Unnamed: 0
# yyyymmdd       0.000000
# hhnn           0.000000
# stn            0.000000
# lon            0.000000
# lat            0.000000
# uv             0.033697
# band1~16       0.011438
# solarza        0.000000
# sateza         0.000000
# esr            0.000000
# height         0.000000
# landtype       0.000000

# %%
df.index.names = ['Columns']
df.columns = ['The ratio of outlier']

# %%
# %matplotlib inline
sns.heatmap(df, annot=False, cmap='seismic')
plt.tight_layout()
plt.savefig('ratio_uv.png')
